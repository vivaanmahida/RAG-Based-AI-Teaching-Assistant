# %%
import joblib
df = joblib.load("embeddings.joblib")
print(df.columns)
print(df.head())
# Out:
# Index(['number', 'title', 'start', 'end', 'text', 'chunk_id', 'embedding'], dtype='object')
#   number                      title  start    end  \
# 0      2  Your First HTML Website     0.00   2.64
# 1      2  Your First HTML Website     2.64   5.04
# 2      2  Your First HTML Website     5.04   6.68
# 3      2  Your First HTML Website     6.68   8.36
# 4      2  Your First HTML Website     8.36  10.76
#
#                                                 text  chunk_id  \
# 0   In the last video, you guys gave me a lot of ...         0
# 1         It's my pleasure to keep this course free.         1
# 2             I deserve a like for this free course.         2
# 3          You know, when I started web development,         3
# 4   there was no comprehensive course of this qua...         4
#
#                                            embedding
# 0  [-0.016871484, 0.0068066344, -0.06314415, 0.00...
# 1  [-0.0520851, -0.019788662, -0.052657496, 0.002...
# ...
